# %%
from utils import *
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['font.family'] = 'Arial'
mpl.rcParams['font.size'] = 16

gC = 1
Nsamples = 50000
rhos = np.linspace(0, 0.8, 101)
R = 4

fig, axs = plt.subplots(1, 3, figsize=(8, 4))

g_diauxs = []
g_couts = []
rho = 0
for i in range(Nsamples):
    g1 = generate_g(1, R)
    g2 = generate_g(1, R)
    gt_1 = (rho+(1-rho)*R)*np.max(g1)
    gt_2 = np.sum(g2)+rho-rho
    g_diauxs.append(1/(1/gt_1+1/gC))
    g_couts.append(1/(1/gt_2+1/gC))
sns.histplot(g_diauxs, ax=axs[0], color="b", alpha = 0.2, stat="density", edgecolor="none", label="Sequential")
sns.histplot(g_couts, ax=axs[0], color="r", alpha = 0.2, stat="density", edgecolor="none", label="Coutilizing")

g_diauxs = []
g_couts = []
rho = 0.28
for i in range(Nsamples):
    g1 = generate_g(1, R)
    g2 = generate_g(1, R)
    gt_1 = (rho+(1-rho)*R)*np.max(g1)
    gt_2 = np.sum(g2)+rho-rho
    g_diauxs.append(1/(1/gt_1+1/gC))
    g_couts.append(1/(1/gt_2+1/gC))
sns.histplot(g_diauxs, ax=axs[1], color="b", alpha = 0.2, stat="density", edgecolor="none", label="Sequential")
sns.histplot(g_couts, ax=axs[1], color="r", alpha = 0.2, stat="density", edgecolor="none", label="Coutilizing")

g_diauxs = []
g_couts = []
rho = 0.4
for i in range(Nsamples):
    g1 = generate_g(1, R)
    g2 = generate_g(1, R)
    gt_1 = (rho+(1-rho)*R)*np.max(g1)
    gt_2 = np.sum(g2)+rho-rho
    g_diauxs.append(1/(1/gt_1+1/gC))
    g_couts.append(1/(1/gt_2+1/gC))
sns.histplot(g_diauxs, ax=axs[2], color="b", alpha = 0.2, stat="density", edgecolor="none", label="Sequential")
sns.histplot(g_couts, ax=axs[2], color="r", alpha = 0.2, stat="density", edgecolor="none", label="Coutilizing")

for idx, ax in enumerate(axs):
    ax.set_xlabel("Growth rate [h$^{-1}$]")
    ax.set_yscale("log")
    ax.set_ylim(1e-2, 50)
    if(idx>0):
        ax.set_ylabel("")
        ax.set_yticks([])
        ax.set_yticklabels([])

fig.tight_layout() 
plt.savefig("../figures/g_dist_diaux_vs_co.pdf", bbox_inches="tight")

# %% [markdown]
# #### new version of the distributions plot: separate median and extreme values

# %%
from utils import *
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['font.family'] = 'Arial'
mpl.rcParams['font.size'] = 16
import matplotlib.pyplot as plt
import numpy as np

gC = 1
Nsamples = 2000
Npool = 500
R = 4

fig, axs = plt.subplots(2, 2, figsize=(7, 4))

g_diauxs_all = []
g_diauxs_max = []
g_couts_all = []
g_couts_max = []
rho = 0.2
for i in range(Nsamples):
    g1 = generate_g(Npool, R)
    g2 = generate_g(Npool, R)
    gt_1 = (rho+(1-rho)*R)*np.max(g1, axis=1)
    gt_2 = np.sum(g2, axis=1)+rho-rho
    g_diauxs_all.extend(list(1/(1/gt_1+1/gC)))
    g_couts_all.extend(list(1/(1/gt_2+1/gC)))
    g_diauxs_max.append(np.max(1/(1/gt_1+1/gC)))
    g_couts_max.append(np.max(1/(1/gt_2+1/gC)))
sns.histplot(g_diauxs_all, ax=axs[0, 0], color="b", alpha = 0.2, stat="density", edgecolor="none", label="Sequential")
sns.histplot(g_couts_all, ax=axs[0, 0], color="r", alpha = 0.2, stat="density", edgecolor="none", label="Coutilizing")
axs[0, 0].set_xlim(0.55, 0.75)
axs[0, 0].set_yticks([])
axs[0, 0].set_yticklabels([])
sns.histplot(g_diauxs_max, ax=axs[1, 0], color="b", alpha = 0.2, stat="density", edgecolor="none", label="Sequential")
sns.histplot(g_couts_max, ax=axs[1, 0], color="r", alpha = 0.2, stat="density", edgecolor="none", label="Coutilizing")
axs[1, 0].set_xlim(0.7, 0.76)
axs[1, 0].set_yticks([])
axs[1, 0].set_yticklabels([])

g_diauxs_all = []
g_diauxs_max = []
g_couts_all = []
g_couts_max = []
rho = 0.3
for i in range(Nsamples):
    g1 = generate_g(Npool, R)
    g2 = generate_g(Npool, R)
    gt_1 = (rho+(1-rho)*R)*np.max(g1, axis=1)
    gt_2 = np.sum(g2, axis=1)+rho-rho
    g_diauxs_all.extend(list(1/(1/gt_1+1/gC)))
    g_couts_all.extend(list(1/(1/gt_2+1/gC)))
    g_diauxs_max.append(np.max(1/(1/gt_1+1/gC)))
    g_couts_max.append(np.max(1/(1/gt_2+1/gC)))
sns.histplot(g_diauxs_all, ax=axs[0, 1], color="b", alpha = 0.2, stat="density", edgecolor="none", label="Sequential")
sns.histplot(g_couts_all, ax=axs[0, 1], color="r", alpha = 0.2, stat="density", edgecolor="none", label="Coutilizing")
axs[0, 1].set_xlim(0.55, 0.75)
axs[0, 1].set_yticks([])
axs[0, 1].set_yticklabels([])
sns.histplot(g_diauxs_max, ax=axs[1, 1], color="b", alpha = 0.2, stat="density", edgecolor="none", label="Sequential")
sns.histplot(g_couts_max, ax=axs[1, 1], color="r", alpha = 0.2, stat="density", edgecolor="none", label="Coutilizing")
axs[1, 1].set_xlim(0.7, 0.76)
axs[1, 1].set_yticks([])
axs[1, 1].set_yticklabels([])

axs[1, 0].set_xlabel("Growth rate [h$^{-1}$]")
axs[1, 1].set_xlabel("Growth rate [h$^{-1}$]")
axs[0, 1].set_ylabel("")
axs[1, 1].set_ylabel("")

fig.tight_layout() 
plt.savefig("../figures/g_dist_diaux_vs_co_nolag.pdf", bbox_inches="tight")

# %%
from utils import *
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['font.family'] = 'Arial'
mpl.rcParams['font.size'] = 16
import matplotlib.pyplot as plt
import numpy as np

gC = 1
Nsamples = 4000
Npool = 500
R = 4

fig, axs = plt.subplots(3, 1, figsize=(7, 6))

g_diauxs_all = []
g_diauxs_max = []
g_couts_all = []
g_couts_max = []
rho = 0.264
for i in range(Nsamples):
    g1 = generate_g(Npool, R)
    g2 = generate_g(Npool, R)
    gt_1 = (rho+(1-rho)*R)*np.max(g1, axis=1)
    gt_2 = np.sum(g2, axis=1)+rho-rho
    g_diauxs_all.extend(list(1/(1/gt_1+1/gC)))
    g_couts_all.extend(list(1/(1/gt_2+1/gC)))
    g_diauxs_max.append(np.max(1/(1/gt_1+1/gC)))
    g_couts_max.append(np.max(1/(1/gt_2+1/gC)))
sns.histplot(g_diauxs_all, ax=axs[0], color="b", alpha = 0.2, stat="density", edgecolor="none", label="Sequential")
sns.histplot(g_couts_all, ax=axs[0], color="r", alpha = 0.2, stat="density", edgecolor="none", label="Coutilizing")
axs[0].axvline(np.median(g_diauxs_all), color="b", alpha=0.35)
axs[0].axvline(np.median(g_couts_all), color="r", alpha=0.35)
axs[0].set_xlim(0.57, 0.76)
axs[0].set_yticks([])
axs[0].set_yticklabels([])
axs[0].set_xticks([0.6, 0.65, 0.7, 0.75])
axs[0].set_title("All 1st niche growth rates")
# axs[0].set_yscale("log")

sns.histplot(g_diauxs_all, ax=axs[1], color="b", alpha = 0.2, stat="density", edgecolor="none", label="Sequential")
sns.histplot(g_couts_all, ax=axs[1], color="r", alpha = 0.2, stat="density", edgecolor="none", label="Coutilizing")
axs[1].set_xlim(0.7, 0.76)
axs[1].set_yticks([])
axs[1].set_yticklabels([])
axs[1].set_yscale("log")

sns.histplot(g_diauxs_max, ax=axs[2], color="b", alpha = 0.2, stat="density", edgecolor="none", label="Sequential")
sns.histplot(g_couts_max, ax=axs[2], color="r", alpha = 0.2, stat="density", edgecolor="none", label="Coutilizing")
axs[2].axvline(np.median(g_diauxs_max), color="b", alpha=0.35)
axs[2].axvline(np.median(g_couts_max), color="r", alpha=0.35)
axs[2].set_xlim(0.7, 0.76)
axs[2].set_yticks([])
axs[2].set_yticklabels([])
axs[2].set_title("Best 1st niche growth rates in community")
# axs[1].set_yscale("log")fig.tight_layout() 

fig.tight_layout()
plt.savefig("../figures/g_dist_diaux_vs_co_nolag.pdf", bbox_inches="tight")

# %%
# Out:
# [0.7770059199140963,
#  0.7695925552455569,
#  0.7722550685719294,
#  0.7691439501038957,
#  0.7698118890097724,
#  0.7697866432663909,
#  0.7785206509089952,
#  0.7582115087116512,
#  0.7620762370826363,
#  0.7775243452409499,
#  0.7705761792079748,
#  0.7708151349116668,
#  0.7798996514118516,
#  0.7740372739391632,
#  0.7803245874405723,
#  0.7675526882365246,
#  0.7637081950028781,
#  0.7728265529595315,
#  0.7845294245123015,
#  0.769175896697593,
#  0.7670435290093266,
#  0.781456573050296,
#  0.7824216834246389,
#  0.773912614151683,
#  0.7767964025641928,
#  0.7702687800132106,
#  0.763658877485968,
#  0.7661780089406686,
#  0.7680900638190393,
#  0.7666307383594952,
#  0.7681993843240412,
#  0.7728969519920204,
#  0.7764308514114244,
#  0.7671227529812997,
#  0.7700916476578892,
#  0.7744590500889512,
#  0.7793271594378657,
#  0.7549208703483047,
#  0.7713643430398028,
#  0.7680993548364231,
#  0.7711495574004547,
#  0.765140477059374,
#  0.7713138263078964,
# ...

# %%
g1
# Out:
# array([[0.69593967, 0.67473695, 0.47639075, 0.76692476],
#        [0.48696763, 0.5235859 , 0.5401849 , 0.73629043],
#        [0.63082507, 0.6958653 , 0.51842058, 0.65920479],
#        ...,
#        [0.4791793 , 0.68795951, 0.51961593, 0.4788279 ],
#        [0.52374778, 0.61566159, 0.28364666, 0.48810694],
#        [0.46117019, 0.5849498 , 0.58117259, 0.49526732]])
